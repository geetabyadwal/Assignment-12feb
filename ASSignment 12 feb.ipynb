# %%
Q1. Wh
t is
n Ex,eption in p

thon? Write the differen,e etween Ex,eptions
nd $
nt
x errors


ANS=    An exception in Python is an event that occurs during the execution of a program, which disrupts the normal flow of the program's instructions. When an exception occurs, Python raises an error message to indicate that something unexpected happened.

There are several types of exceptions in Python, including:

SyntaxError: Occurs when the syntax of a statement or expression is incorrect.

NameError: Occurs when a variable or function name is not defined in the current scope.

TypeError: Occurs when an operation or function is applied to an object of inappropriate type.

ValueError: Occurs when a built-in operation or function receives an argument that has the right type but an inappropriate value.

IndexError: Occurs when trying to access an index that is out of range in a list or tuple.

The main difference between exceptions and syntax errors is that syntax errors occur during the parsing of code and are usually caught by the Python interpreter before the program runs. Exceptions, on the other hand, occur during program execution and can be caught and handled by the program code.

Another difference between exceptions and runtime errors is that runtime errors occur when a program violates a language or system-specific runtime constraint, such as dividing by zero, while exceptions are raised by the Python interpreter or program code when an error condition is encountered during program execution.
Q2. Wh
t h
ppens when

n ex,eption is not h

ndled? Expl
in with
n ex
mple

ANS=def divide_by_zero():
    x = 1 / 0

divide_by_zero()
n this example, the divide_by_zero function attempts to divide the number 1 by zero, which is not a valid operation in Python. This will raise a ZeroDivisionError exception. However, the exception is not handled within the function, so it will propagate up to the calling code and cause the program to terminate with an error message:
Traceback (most recent call last):
  File "example.py", line 4, in <module>
    divide_by_zero()
  File "example.py", line 2, in divide_by_zero
    x = 1 / 0
ZeroDivisionError: division by zero

Q3. Whi,h P
thon st
tements

re used to ,
t,h
nd h
ndle ex,eptions? Expl
in with
n ex
mple

ANS=def divide(x, y):
    try:
        result = x / y
    except ZeroDivisionError:
        print("Error: division by zero")
        result = None
    return result

print(divide(10, 2))  # Output: 5.0
print(divide(10, 0))  # Output: Error: division by zero, None

Q4. Expl
in with
n ex
mple:#

 tr
nd else#
 fin
ll
+ r
ise

 ANS=   def divide(x, y):
    try:
        result = x / y
    except ZeroDivisionError:
        print("Error: division by zero")
        result = None
    else:
        print("Division successful")
    finally:
        print("Cleanup code executed")
    return result

print(divide(10, 2))  # Output: Division successful, Cleanup code executed, 5.0
print(divide(10, 0))  # Output: Error: division by zero, Cleanup code executed, None

Q5. Wh
t
re Custom Ex,eptions in p

thon? Wh

do we need Custom Ex,eptions? Expl
in with
n ex
mple
ANS=We need custom exceptions to provide more detailed and specific error messages when an exceptional condition occurs in our program. Custom exceptions can help us to identify the root cause of an error more quickly and make it easier to handle errors in a structured way.
